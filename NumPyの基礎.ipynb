# %% [markdown]
# NumPyのインポート
# 次の1行で、数学的な数値計算を行うツール群を呼び出します。　色々な計算が入っています。中身を全て覚える必要などありません。　むしろ、使いたい時にきちんと調べる癖をつけましょう。
# このファイルをcolab上から見ている時、[ ] の　▶︎マークをクリックすると、1行ずつ実行してくれますので、実行してみてください。

# %%
import numpy

# %% [markdown]
# 次の1行は、numpy を　np と略称で使うことを宣言しています。

# %%
import numpy as np

# %% [markdown]
# NumPyの配列を生成
#
# 次の行は、計算しやすいように配列を作り、その下のprint文で中身を表示します。
#
# いよいよ　colabを使った　コンピューティング実験の始まりです。
# 　ただ単にクリックして読むだけではなく、数値を変えて実行してみましょう。　また、a という文字を違う文字に変えてみましょう。

# %%
import numpy as np

a = np.array([0, 1, 2, 3, 4, 5]) #PythonのリストからNumPyの配列を作る
print(a)

# %% [markdown]
#  ２次元配列は、行列として数学では習います。
# 白黒画像のデータなども2次元配列の１つです。様々な応用があります

# %%
import numpy as np

b = np.array([[0, 1, 2], [3, 4, 5]]) #2重のリストからNumPyの2次元配列を作る
print(b)

# %% [markdown]
# 3次元配列は、馴染みがあまりないかもしれませんが、カラー画像は3次元配列のデータです。
# 中身の数値を変えて、代入できているか、確認してください。
#
# 同じ12個の数値であっても、1次元配列、2次元配列、3次元配列、全て数値データにアクセス（読み書き）する方法は異なります。

# %%
import numpy as np

c = np.array([[[0, 1, 2], [3, 4, 5]], [[5, 4, 3], [2, 1, 0]]]) #3重のリストからNumPyの3次元配列を作る
print(c)

# %%
import numpy as np

d = np.zeros(8) #0が8個格納された配列
print(d)

e = np.ones(8) #1が8個格納された配列
print(e)

f = np.arange(8) #0から7までが格納された配列
print(f)

# %% [markdown]
# 配列の形状

# %%
import numpy as np

a = np.array([[0, 1, 2], [3, 4, 5]]) #2x3の2次元配列
print(np.shape(a)) #aの形状を表示

# %%
print(len(a)) #aの行数を得る

# %% [markdown]
# 配列の演算

# %%
import numpy as np

a = np.array([[0, 1, 2], [3, 4, 5]]) #2次元配列

print(a)
print()
print(a + 3) #各要素に3を足す
print()
print(a * 3) #各要素に3を掛ける

# %%
b = np.array([[0, 1, 2], [3, 4, 5]]) #2次元配列

c = np.array([[2, 0, 1], [5, 3, 4]]) #2次元配列

print(b)
print()
print(c)
print()
print(b + c)
print()
print(b * c)

# %% [markdown]
# 要素へのアクセス

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])
print(a[3]) #インデックスを指定

# %%
a[2] = 9
print(a)

# %%
b = np.array([[0, 1, 2], [3, 4, 5]])

print(b[1, 2]) #b[1][2]と同じ

# %%
b[1, 2] = 9

print(b)

# %%
c = np.array([[0, 1, 2], [3, 4, 5]])

print(c[1, :]) #インデックスが1の行を取得

print()

c[:, 1] = np.array([6, 7]) #インデックスが1の列を入れ替え
print(c)

# %% [markdown]
# 関数と配列

# %%
import numpy as np

def my_func(x):
  y = x * 2 + 1
  return y

a = np.array([[0, 1, 2], [3, 4, 5]]) #2次元配列
b = my_func(a) #引数として配列を渡し、返り値として配列を受け取る

print(b)

# %% [markdown]
# NumPyの様々な機能

# %%
import numpy as np

a = np.array([[0, 1, 2], [3, 4, 5]]) #2次元配列

print("合計:", np.sum(a))
print("平均:", np.average(a))
print("最大値:", np.max(a))
print("最小値:", np.min(a))

# %% [markdown]
# 演習

# %%
import numpy as np

a = np.array([[0, 1, 2], [3, 4, 5]])
b = np.array([[5, 4, 3], [2, 1, 0]])

print(a + b) #和
print()
print(a - b) #差
print()
print(a * b) #積
